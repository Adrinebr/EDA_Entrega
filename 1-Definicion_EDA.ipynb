# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Analisis historico de La Liga española de futbol"

# %% [markdown]
# **Analisis historico de La Liga española de futbol**

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = ""

# %% [markdown]
# Analizar los resultados historicos de La Liga y relacionarlos con las estadísticas individuales como colectivas de los tres primeros clasificados y los colistas.

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = ""

# %% [markdown]
# *Hipotesis 1*
#
# Se guarda una relación entre salir campeón, ser el equipo más goleador, tener al pichichi de la liga y al portero menos goleado.

# %%
# Escribe más hipótesis si las hubiera en Markdown
# hipotesis_2 = ""
# hipotesis_3 = ""
# hipotesis_4 = ""
# hipotesis_5 = ""
# ...

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
df_1 = pd.DataFrame()
fuente_1 = ""
df_LaLiga = pd.read_csv("./data/EDA_LaLiga.csv")
df_LaLiga.info()
# df_2 = pd.DataFrame()
# fuente_2 = ""
# df_3 = pd.DataFrame()
# fuente_3 = ""
# df_4 = pd.DataFrame()
# fuente_4 = ""
# df_5 = pd.DataFrame()
# fuente_5 = ""
# ...
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 55 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Temporada              92 non-null     object
#  1   Equipos                92 non-null     int64
#  2   Jornadas               92 non-null     int64
#  3   Campeón                92 non-null     object
#  4   PJ_Campeon             92 non-null     int64
#  5   PG_Campeon             92 non-null     int64
#  6   PE_Campeon             92 non-null     int64
#  7   PP_Campeon             92 non-null     int64
#  8   GF_Campeon             92 non-null     int64
#  9   GC_Campeon             92 non-null     int64
#  10  Puntos_Campeon         92 non-null     int64
#  11  Subcampeón             92 non-null     object
#  12  PJ_Subcampeon          92 non-null     int64
#  13  PG_Subcampeon          92 non-null     int64
#  14  PE_Subcampeon          92 non-null     int64
# ...

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
df_LaLiga.head(10)
df_LaLiga
# Out:
#    Temporada  Equipos  Jornadas             Campeón  PJ_Campeon  PG_Campeon  \
# 0    1928-29       10        18     F. C. Barcelona          18          11
# 1    1929-30       10        18       Athletic Club          18          12
# 2    1930-31       10        18       Athletic Club          18          11
# 3    1931-32       10        18   Real Madrid C. F.          18          10
# 4    1932-33       10        18   Real Madrid C. F.          18          13
# ..       ...      ...       ...                 ...         ...         ...
# 87   2018-19       20        38     F. C. Barcelona          38          26
# 88   2019-20       20        38   Real Madrid C. F.          38          26
# 89   2020-21       20        38  Atlético de Madrid          38          26
# 90   2021-22       20        38   Real Madrid C. F.          38          26
# 91   2022-23       20        38     F. C. Barcelona          38          28
#
# ...

# %%
df_LaLiga[76:90]
# Out:
#    Temporada  Equipos  Jornadas             Campeón  PJ_Campeon  PG_Campeon  \
# 76   2007-08       20        38   Real Madrid C. F.          38          27
# 77   2008-09       20        38     F. C. Barcelona          38          27
# 78   2009-10       20        38     F. C. Barcelona          38          31
# 79   2010-11       20        38     F. C. Barcelona          38          30
# 80   2011-12       20        38   Real Madrid C. F.          38          32
# 81   2012-13       20        38     F. C. Barcelona          38          32
# 82   2013-14       20        38  Atlético de Madrid          38          28
# 83   2014-15       20        38     F. C. Barcelona          38          30
# 84   2015-16       20        38     F. C. Barcelona          38          29
# 85   2016-17       20        38   Real Madrid C. F.          38          29
# 86   2017-18       20        38     F. C. Barcelona          38          28
# ...

# %%
df_LaLiga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 55 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Temporada              92 non-null     object
#  1   Equipos                92 non-null     int64
#  2   Jornadas               92 non-null     int64
#  3   Campeón                92 non-null     object
#  4   PJ_Campeon             92 non-null     int64
#  5   PG_Campeon             92 non-null     int64
#  6   PE_Campeon             92 non-null     int64
#  7   PP_Campeon             92 non-null     int64
#  8   GF_Campeon             92 non-null     int64
#  9   GC_Campeon             92 non-null     int64
#  10  Puntos_Campeon         92 non-null     int64
#  11  Subcampeón             92 non-null     object
#  12  PJ_Subcampeon          92 non-null     int64
#  13  PG_Subcampeon          92 non-null     int64
#  14  PE_Subcampeon          92 non-null     int64
# ...
